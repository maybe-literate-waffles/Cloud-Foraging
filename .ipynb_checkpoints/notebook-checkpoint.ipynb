# %%
import json
from IPython.display import JSON
import pandas as pnd
from main import get_weather_data
from main import data_func

data = data_func()

df = pnd.DataFrame([data])
# JSON(weather)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 9
#       5 from main import data_func
#       6
#       7 data = data_func()
#       8
# ----> 9 df = pnd.DataFrame(data)
#      10 # JSON(weather)
#      11
#      12 df.head()
#
# File ~/Desktop/code/Projects/Cloud-Foraging/.venv/lib/python3.14/site-packages/pandas/core/frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# File ~/Desktop/code/Projects/Cloud-Foraging/.venv/lib/python3.14/site-packages/pandas/core/internals/construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File ~/Desktop/code/Projects/Cloud-Foraging/.venv/lib/python3.14/site-packages/pandas/core/internals/construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File ~/Desktop/code/Projects/Cloud-Foraging/.venv/lib/python3.14/site-packages/pandas/core/internals/construction.py:634, in _extract_index(data)
#     631         raise ValueError("Per-column arrays must each be 1-dimensional")
#     633 if not indexes and not raw_lengths:
# --> 634     raise ValueError("If using all scalar values, you must pass an index")
#     636 if have_series:
#     637     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index
